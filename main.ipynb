# %% [markdown]
# ## 처음 세팅 시에만

# %%
# Google Drive 마운트
from google.colab import drive
drive.mount('/content/drive')

# %cd /content/drive/MyDrive/B.S.degree
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/MyDrive/B.S.degree

# %%
import os
from google.colab import userdata
os.environ['GITHUB_TOKEN'] = userdata.get('GITHUB_TOKEN')

# !git config --global credential.helper store
# !git config --global user.email "modifymeter@naver.com"
# !git config --global user.name "Hwaaanss"

# 1. GitHub 레포지토리 주소 설정
## %env REPO_URL=https://{github_id}:{personal_access_token}@github.com/{github_id}/test.git
REPO_URL = f"https://Hwaaanss:{os.environ['GITHUB_TOKEN']}@github.com/Hwaaanss/Capstone2_HelloKitty.git"

# 2. 레포지토리 클론 (이미 클론했다면 생략)
# !git clone {REPO_URL}

# 3. 클론된 레포지토리 폴더로 이동
# %cd {repository_name}
# %cd Capstone2_HelloKitty

# 4. Git LFS 설치 및 설정 (최초 한 번만 실행)
# !git lfs install

# 5. Git LFS로 관리할 파일 확장자 지정 (예: .pth, .h5, .pt 등 모델 가중치 파일)
# !git lfs track "*.pth"
# !git lfs track "*.h5"

# 6. .gitattributes 파일이 생성되었는지 확인하고, 이 파일을 커밋 대상에 추가
# !git add .gitattributes

# 7. 변경된 모든 파일을 스테이징(Staging) 영역에 추가
# !git add .

# 8. 변경 사항에 대한 메시지와 함께 커밋
# !git commit -m "Colab 노트북과 모델 가중치 추가"

# 9. GitHub 레포지토리로 푸시
# !git push --no-verify
# Out:
# env: REPO_URL=https://Hwaaanss:$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@github.com/Hwaaanss/Capstone2_HelloKitty.git
# fatal: destination path 'Capstone2_HelloKitty' already exists and is not an empty directory.
# /content/drive/MyDrive/B.S.degree/Capstone2_HelloKitty
# Updated git hooks.
# Git LFS initialized.
# "*.pth" already supported
# "*.h5" already supported

# %%
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean
# Everything up-to-date

# %% [markdown]
# ## 이후 작업 시

# %%
# Google Drive 마운트
from google.colab import drive
drive.mount('/content/drive')

# %cd /content/drive/MyDrive/B.S.degree
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/B.S.degree

# %%
import os
from google.colab import userdata
os.environ['GITHUB_TOKEN'] = userdata.get('GITHUB_TOKEN')

# !git config --global credential.helper store
# !git config --global user.email "modifymeter@naver.com"
# !git config --global user.name "Hwaaanss"

# 1. GitHub 레포지토리 주소 설정
## %env REPO_URL=https://{github_id}:{personal_access_token}@github.com/{github_id}/test.git
REPO_URL = f"https://Hwaaanss:{os.environ['GITHUB_TOKEN']}@github.com/Hwaaanss/Capstone2_HelloKitty.git"

# 2. 레포지토리 클론 (버전 꼬이는걸 방지하기 위해 매번 실행하는거 추천)
# !git clone {REPO_URL}
# Out:
# fatal: destination path 'Capstone2_HelloKitty' already exists and is not an empty directory.

# %%
# 3. 클론된 레포지토리 폴더로 이동
## %cd {repository_name}
# %cd Capstone2_HelloKitty

# 4. Git LFS 설치 및 설정
# !git lfs install

# 5. Git LFS로 관리할 파일 확장자 지정 (예: .pth, .h5, .pt 등 모델 가중치 파일들도 커밋하려면 추가 후 6번으로 반영)
## !git lfs track "*.{확장자명}"

# 6. .gitattributes 파일이 생성되었는지 확인하고, 이 파일을 커밋 대상에 추가
## !git add .gitattributes
# Out:
# /content/drive/MyDrive/B.S.degree/Capstone2_HelloKitty
# mkdir /dev/null: not a directory
# To resolve this, either:
#   1: run `git lfs update --manual` for instructions on how to merge hooks.
#   2: run `git lfs update --force` to overwrite your hook.

# %%
## 버젼 꼬이면 깃허브 기준으로 병합해오기
# !git pull origin main --no-rebase --no-edit
# Out:
# From https://github.com/Hwaaanss/Capstone2_HelloKitty
#  * branch            main       -> FETCH_HEAD
# Already up to date.

# %%
####### 작업 후
# 변경된 모든 파일을 스테이징(Staging) 영역에 추가
# !git add .

# 변경 사항에 대한 메시지와 함께 커밋
# !git commit -m "delete unnecessary files"

# GitHub 레포지토리로 푸시
# !git push --no-verify

# %% [markdown]
# #### 강제 push

# %%
#### 강제 push
# 진행 중인 rebase/merge를 포기
# !git rebase --abort
# !git merge --abort   # merge 도중이면

# 로컬 변경 사항을 강제로 원격에 올림
# !git add .
# !git commit -m "로컬 변경 강제 반영"
# !git push origin main --force
# Out:
# fatal: No rebase in progress?
# fatal: There is no merge to abort (MERGE_HEAD missing).
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean
# Everything up-to-date

# %% [markdown]
# ## Data Preprocessing

# %%
import gc
import math
import calendar
from datetime import datetime
import pandas as pd

# %%
data1 = pd.read_csv('/content/drive/MyDrive/B.S.degree/Capstone2_HelloKitty/dataset/big_data_set1_f.csv', encoding='cp949')
data2 = pd.read_csv('/content/drive/MyDrive/B.S.degree/Capstone2_HelloKitty/dataset/big_data_set2_f.csv', encoding='cp949')
data3 = pd.read_csv('/content/drive/MyDrive/B.S.degree/Capstone2_HelloKitty/dataset/big_data_set3_f.csv', encoding='cp949')

data = pd.merge(data2, data3, on=['ENCODED_MCT' ,'TA_YM'], how='inner')
data = pd.merge(data, data1, on='ENCODED_MCT', how='left')

del data1, data2, data3
gc.collect()

data
# Out:
#       ENCODED_MCT   TA_YM       MCT_OPE_MS_CN           RC_M1_SAA  \
# 0      000F03E44A  202404            4_50-75%            5_75-90%
# 1      000F03E44A  202312            4_50-75%  6_90%초과(하위 10% 이하)
# 2      002816BA73  202404            2_10-25%            3_25-50%
# 3      002816BA73  202411            2_10-25%            3_25-50%
# 4      002816BA73  202406            2_10-25%            4_50-75%
# ...           ...     ...                 ...                 ...
# 86585  A2D9C941A9  202304            5_75-90%            2_10-25%
# 86586  A7C2307794  202303            2_10-25%            2_10-25%
# 86587  BF6A6456AB  202407  6_90%초과(하위 10% 이하)            2_10-25%
# 86588  C59F032CAC  202406             1_10%이하            2_10-25%
# 86589  F46D45E328  202302            2_10-25%            2_10-25%
#
#            RC_M1_TO_UE_CT     RC_M1_UE_CUS_CN      RC_M1_AV_NP_AT  \
# 0                5_75-90%            5_75-90%            5_75-90%
# ...

# %% [markdown]
# #### Drop columns

# %%
data['MCT_BRD_NUM'].isnull().sum()
# Out:
# np.int64(74865)

# %%
data['HPSN_MCT_BZN_CD_NM'].isnull().sum()
# Out:
# np.int64(21419)

# %%
data['MCT_SIGUNGU_NM'].value_counts()  ## drop 확정
# Out:
# MCT_SIGUNGU_NM
# 서울 성동구    86590
# Name: count, dtype: int64

# %%
data['MCT_NM'].value_counts()  ## 비식별화 때문에 업종 등 어떠한 정보도 얻을 수 없음.

# %%
data['MCT_BSE_AR'].value_counts()  ## drop 확정
# Out:
# MCT_BSE_AR
# 서울특별시 성동구 왕십리로 410           1430
# 서울특별시 성동구 마장로 137             685
# 서울특별시 성동구 왕십리광장로 17           555
# 서울  성동구  마장동                  504
# 서울특별시 성동구 무학로6길 50            399
# 서울특별시 성동구 무학로 33              279
# 서울 성동구 살곶이길 18.               278
# 서울특별시 성동구 자동차시장1길 70          249
# 서울 성동구 마장로 137.               248
# 서울 성동구 마조로 17.                240
# 서울특별시 성동구 마조로 17              203
# 서울 성동구 마장동                    192
# 서울특별시 성동구 성수일로10길 26          178
# 서울특별시 성동구 연무장5가길 25           177
# 서울특별시 성동구 광나루로6길 35           175
# 서울특별시 성동구 마장로35길 76           170
# 서울  성동구  행당동                  168
# 서울특별시 성동구 동일로 143             161
# 서울특별시 성동구 행당로 84              156
# 서울특별시 성동구 왕십리로 222            155
# 서울  성동구  성수2가1동               144
# 서울특별시 성동구 아차산로15길 10          141
# 서울특별시 성동구 마장로37길 40           130
# 서울특별시 성동구 행당로 87              128
# 서울특별시 성동구 매봉길 50              122
# 서울특별시 성동구 마장로31길 43           120
# 서울  성동구  옥수2동                 120
# ...

# %%
data_prep = data.drop(columns=['MCT_BRD_NUM', 'MCT_SIGUNGU_NM', 'MCT_NM', 'MCT_BSE_AR', 'MCT_BSE_AR'])
data_prep
# Out:
#       ENCODED_MCT   TA_YM       MCT_OPE_MS_CN           RC_M1_SAA  \
# 0      000F03E44A  202404            4_50-75%            5_75-90%
# 1      000F03E44A  202312            4_50-75%  6_90%초과(하위 10% 이하)
# 2      002816BA73  202404            2_10-25%            3_25-50%
# 3      002816BA73  202411            2_10-25%            3_25-50%
# 4      002816BA73  202406            2_10-25%            4_50-75%
# ...           ...     ...                 ...                 ...
# 86585  A2D9C941A9  202304            5_75-90%            2_10-25%
# 86586  A7C2307794  202303            2_10-25%            2_10-25%
# 86587  BF6A6456AB  202407  6_90%초과(하위 10% 이하)            2_10-25%
# 86588  C59F032CAC  202406             1_10%이하            2_10-25%
# 86589  F46D45E328  202302            2_10-25%            2_10-25%
#
#            RC_M1_TO_UE_CT     RC_M1_UE_CUS_CN      RC_M1_AV_NP_AT  \
# 0                5_75-90%            5_75-90%            5_75-90%
# ...

# %%
data_prep.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 86590 entries, 0 to 86589
# Data columns (total 34 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   ENCODED_MCT               86590 non-null  object
#  1   TA_YM                     86590 non-null  int64
#  2   MCT_OPE_MS_CN             86590 non-null  object
#  3   RC_M1_SAA                 86590 non-null  object
#  4   RC_M1_TO_UE_CT            86590 non-null  object
#  5   RC_M1_UE_CUS_CN           86590 non-null  object
#  6   RC_M1_AV_NP_AT            86590 non-null  object
#  7   APV_CE_RAT                79958 non-null  object
#  8   DLV_SAA_RAT               86590 non-null  float64
#  9   M1_SME_RY_SAA_RAT         86590 non-null  float64
#  10  M1_SME_RY_CNT_RAT         86590 non-null  float64
#  11  M12_SME_RY_SAA_PCE_RT     86590 non-null  float64
#  12  M12_SME_BZN_SAA_PCE_RT    86590 non-null  float64
# ...

# %%
columns_to_split = ['MCT_OPE_MS_CN', 'RC_M1_SAA', 'RC_M1_TO_UE_CT','RC_M1_UE_CUS_CN','RC_M1_AV_NP_AT','APV_CE_RAT']

for c in columns_to_split:
    mask = data_prep[c].notna()
    data_prep.loc[mask, c] = data_prep.loc[mask, c].astype(str).str.split('_').str[0].astype(int)
data_prep
# Out:
#       ENCODED_MCT   TA_YM MCT_OPE_MS_CN RC_M1_SAA RC_M1_TO_UE_CT  \
# 0      000F03E44A  202404             4         5              5
# 1      000F03E44A  202312             4         6              6
# 2      002816BA73  202404             2         3              4
# 3      002816BA73  202411             2         3              4
# 4      002816BA73  202406             2         4              4
# ...           ...     ...           ...       ...            ...
# 86585  A2D9C941A9  202304             5         2              1
# 86586  A7C2307794  202303             2         2              2
# 86587  BF6A6456AB  202407             6         2              4
# 86588  C59F032CAC  202406             1         2              2
# 86589  F46D45E328  202302             2         2              3
#
#       RC_M1_UE_CUS_CN RC_M1_AV_NP_AT APV_CE_RAT  DLV_SAA_RAT  \
# 0                   5              5          1    -999999.9
# ...

# %%
data_prep['HPSN_MCT_BZN_CD_NM'].fillna('비상권', inplace=True)
# Out:
# /tmp/ipython-input-1637789189.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data_prep['HPSN_MCT_BZN_CD_NM'].fillna('비상권', inplace=True)

# %%
data_prep
# Out:
#       ENCODED_MCT   TA_YM MCT_OPE_MS_CN RC_M1_SAA RC_M1_TO_UE_CT  \
# 0      000F03E44A  202404             4         5              5
# 1      000F03E44A  202312             4         6              6
# 2      002816BA73  202404             2         3              4
# 3      002816BA73  202411             2         3              4
# 4      002816BA73  202406             2         4              4
# ...           ...     ...           ...       ...            ...
# 86585  A2D9C941A9  202304             5         2              1
# 86586  A7C2307794  202303             2         2              2
# 86587  BF6A6456AB  202407             6         2              4
# 86588  C59F032CAC  202406             1         2              2
# 86589  F46D45E328  202302             2         2              3
#
#       RC_M1_UE_CUS_CN RC_M1_AV_NP_AT APV_CE_RAT  DLV_SAA_RAT  \
# 0                   5              5          1    -999999.9
# ...

# %%
data_prep.to_csv('/content/drive/MyDrive/B.S.degree/Capstone2_HelloKitty/dataset/BasicData_Prep3.csv', encoding='cp949')

# %%
data_prep = pd.read_csv('/content/drive/MyDrive/B.S.degree/Capstone2_HelloKitty/dataset/BasicData_Prep3.csv', encoding='cp949').drop(columns='Unnamed: 0').sort_values(by=['ENCODED_MCT', 'TA_YM'])
data_prep
# Out:
#       ENCODED_MCT   TA_YM  MCT_OPE_MS_CN  RC_M1_SAA  RC_M1_TO_UE_CT  \
# 46117  000F03E44A  202301              5          6               5
# 27145  000F03E44A  202302              5          6               6
# 27144  000F03E44A  202303              5          6               6
# 51842  000F03E44A  202304              5          6               5
# 34110  000F03E44A  202305              5          6               5
# ...           ...     ...            ...        ...             ...
# 81837  FFF0DAC445  202408              3          2               3
# 19731  FFF0DAC445  202409              3          1               3
# 34109  FFF0DAC445  202410              3          2               3
# 40932  FFF0DAC445  202411              3          2               3
# 86579  FFF0DAC445  202412              3          2               3
#
#        RC_M1_UE_CUS_CN  RC_M1_AV_NP_AT  APV_CE_RAT  DLV_SAA_RAT  \
# 46117                5               4         1.0    -999999.9
# ...

# %%
for c in data_prep.columns:
    nann = data_prep[c].isnull().sum()
    if nann != 0:
        print(f'{c} : {nann}/{86590} ({nann/86590})')
# Out:
# APV_CE_RAT : 6632/86590 (0.07659083034992493)
# MCT_ME_D : 84256/86590 (0.9730453863032683)

# %%
data_prep['MCT_ME_D'].unique()
# Out:
# array([      nan, 20250723., 20250819., 20250702., 20230417., 20250730.,
#        20250714., 20250801., 20240521., 20250729., 20250811., 20250814.,
#        20240903., 20250717., 20230504., 20250731., 20250728., 20250716.,
#        20250805., 20250722., 20250407., 20230515., 20250708., 20230530.,
#        20231031., 20230913., 20231113., 20250408., 20250721., 20250818.,
#        20250707., 20250718., 20250808., 20250704., 20250710., 20240710.,
#        20250107., 20241010., 20250820., 20230911., 20250703., 20230105.,
#        20250725., 20250804., 20250514., 20230418., 20250806., 20240426.,
#        20250822., 20240729., 20230821., 20250709., 20250610., 20250821.,
#        20250117., 20240528., 20250724., 20240627., 20230822., 20231018.,
#        20240514., 20241114., 20240402., 20250813., 20240102., 20250715.,
#        20231127., 20240305., 20250214., 20241028., 20240808., 20250220.,
#        20230321.])

# %%
data_prep['ARE_D'] = pd.to_numeric(data_prep['ARE_D'], errors='coerce')
data_prep['MCT_ME_D'] = pd.to_numeric(data_prep['MCT_ME_D'], errors='coerce')

data_prep['ARE_D'] = data_prep['ARE_D'].astype('Int64')
data_prep['MCT_ME_D'] = data_prep['MCT_ME_D'].astype('Int64')

na_rows = data_prep['MCT_ME_D'].isna()
data_prep['survive'] = na_rows
data_prep
# Out:
#       ENCODED_MCT   TA_YM  MCT_OPE_MS_CN  RC_M1_SAA  RC_M1_TO_UE_CT  \
# 46117  000F03E44A  202301              5          6               5
# 27145  000F03E44A  202302              5          6               6
# 27144  000F03E44A  202303              5          6               6
# 51842  000F03E44A  202304              5          6               5
# 34110  000F03E44A  202305              5          6               5
# ...           ...     ...            ...        ...             ...
# 81837  FFF0DAC445  202408              3          2               3
# 19731  FFF0DAC445  202409              3          1               3
# 34109  FFF0DAC445  202410              3          2               3
# 40932  FFF0DAC445  202411              3          2               3
# 86579  FFF0DAC445  202412              3          2               3
#
#        RC_M1_UE_CUS_CN  RC_M1_AV_NP_AT  APV_CE_RAT  DLV_SAA_RAT  \
# 46117                5               4         1.0    -999999.9
# ...

# %%
for idx in data_prep.index:
    tmp = data_prep.loc[idx]
    try:
        if tmp['TA_YM'] == tmp['MCT_ME_D']//100:
            data_prep.loc[idx, 'survive'] = 0
        else:
            data_prep.loc[idx, 'survive'] = 1
    except:
        data_prep.loc[idx, 'survive'] = 1

data_prep
# Out:
# /tmp/ipython-input-2165275645.py:9: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '1' has dtype incompatible with bool, please explicitly cast to a compatible dtype first.
#   data_prep.loc[idx, 'survive'] = 1
#       ENCODED_MCT   TA_YM  MCT_OPE_MS_CN  RC_M1_SAA  RC_M1_TO_UE_CT  \
# 46117  000F03E44A  202301              5          6               5
# 27145  000F03E44A  202302              5          6               6
# 27144  000F03E44A  202303              5          6               6
# 51842  000F03E44A  202304              5          6               5
# 34110  000F03E44A  202305              5          6               5
# ...           ...     ...            ...        ...             ...
# 81837  FFF0DAC445  202408              3          2               3
# 19731  FFF0DAC445  202409              3          1               3
# 34109  FFF0DAC445  202410              3          2               3
# ...

# %%
data_prep.loc[data_prep['ENCODED_MCT']=='1521FF7269']
# Out:
#       ENCODED_MCT   TA_YM  MCT_OPE_MS_CN  RC_M1_SAA  RC_M1_TO_UE_CT  \
# 39512  1521FF7269  202301              5          4               4
# 64062  1521FF7269  202302              5          4               4
# 10531  1521FF7269  202303              5          4               4
# 35075  1521FF7269  202304              5          4               4
# 41059  1521FF7269  202305              5          3               4
# 36643  1521FF7269  202306              5          4               4
# 61067  1521FF7269  202307              5          3               4
# 847    1521FF7269  202308              5          3               4
# 845    1521FF7269  202309              5          3               4
# 37925  1521FF7269  202310              4          3               4
# 10533  1521FF7269  202311              4          4               4
# 846    1521FF7269  202312              4          4               4
# 80415  1521FF7269  202401              4          4               4
# ...

# %%
data_prep.loc[data_prep['ENCODED_MCT']=='000F03E44A']
# Out:
#       ENCODED_MCT   TA_YM  MCT_OPE_MS_CN  RC_M1_SAA  RC_M1_TO_UE_CT  \
# 46117  000F03E44A  202301              5          6               5
# 27145  000F03E44A  202302              5          6               6
# 27144  000F03E44A  202303              5          6               6
# 51842  000F03E44A  202304              5          6               5
# 34110  000F03E44A  202305              5          6               5
# 49032  000F03E44A  202306              5          6               5
# 42387  000F03E44A  202307              5          6               6
# 18161  000F03E44A  202308              5          6               6
# 32547  000F03E44A  202309              5          6               5
# 12868  000F03E44A  202310              5          6               6
# 50508  000F03E44A  202311              4          6               5
# 1      000F03E44A  202312              4          6               6
# 21946  000F03E44A  202401              4          6               6
# ...

# %%
def get_last_day_from_yyyymm(yyyymm):
    if pd.isna(yyyymm):
        return None
    y = int(yyyymm // 100)
    m = int(yyyymm % 100)
    d = calendar.monthrange(y, m)[1]
    return y * 10000 + m * 100 + d

replacement_dates = data_prep.loc[na_rows, 'TA_YM'].apply(get_last_day_from_yyyymm)

data_prep['MCT_ME_D'] = data_prep['MCT_ME_D'].fillna(replacement_dates)

date1_series = pd.to_datetime(data_prep['ARE_D'].astype(str), format='%Y%m%d', errors='coerce')
date2_series = pd.to_datetime(data_prep['MCT_ME_D'].astype(str), format='%Y%m%d', errors='coerce')

data_prep['day_diff'] = (date2_series - date1_series).dt.days.abs()

data_prep
# Out:
#       ENCODED_MCT   TA_YM  MCT_OPE_MS_CN  RC_M1_SAA  RC_M1_TO_UE_CT  \
# 46117  000F03E44A  202301              5          6               5
# 27145  000F03E44A  202302              5          6               6
# 27144  000F03E44A  202303              5          6               6
# 51842  000F03E44A  202304              5          6               5
# 34110  000F03E44A  202305              5          6               5
# ...           ...     ...            ...        ...             ...
# 81837  FFF0DAC445  202408              3          2               3
# 19731  FFF0DAC445  202409              3          1               3
# 34109  FFF0DAC445  202410              3          2               3
# 40932  FFF0DAC445  202411              3          2               3
# 86579  FFF0DAC445  202412              3          2               3
#
#        RC_M1_UE_CUS_CN  RC_M1_AV_NP_AT  APV_CE_RAT  DLV_SAA_RAT  \
# 46117                5               4         1.0    -999999.9
# ...

# %%
data_prep.drop(columns=['ARE_D','MCT_ME_D'], inplace=True)
data_prep
# Out:
#       ENCODED_MCT   TA_YM  MCT_OPE_MS_CN  RC_M1_SAA  RC_M1_TO_UE_CT  \
# 46117  000F03E44A  202301              5          6               5
# 27145  000F03E44A  202302              5          6               6
# 27144  000F03E44A  202303              5          6               6
# 51842  000F03E44A  202304              5          6               5
# 34110  000F03E44A  202305              5          6               5
# ...           ...     ...            ...        ...             ...
# 81837  FFF0DAC445  202408              3          2               3
# 19731  FFF0DAC445  202409              3          1               3
# 34109  FFF0DAC445  202410              3          2               3
# 40932  FFF0DAC445  202411              3          2               3
# 86579  FFF0DAC445  202412              3          2               3
#
#        RC_M1_UE_CUS_CN  RC_M1_AV_NP_AT  APV_CE_RAT  DLV_SAA_RAT  \
# 46117                5               4         1.0    -999999.9
# ...

# %%
data_prep.to_csv('/content/drive/MyDrive/B.S.degree/Capstone2_HelloKitty/dataset/BasicData_Prep3.csv', encoding='cp949')

# %%
data_prep2 = pd.read_csv('/content/drive/MyDrive/B.S.degree/Capstone2_HelloKitty/dataset/BasicData_Prep3.csv', encoding='cp949').drop(columns='Unnamed: 0').sort_values(by=['ENCODED_MCT', 'TA_YM'])
data_prep2
# Out:
#       ENCODED_MCT   TA_YM  MCT_OPE_MS_CN  RC_M1_SAA  RC_M1_TO_UE_CT  \
# 0      000F03E44A  202301              5          6               5
# 1      000F03E44A  202302              5          6               6
# 2      000F03E44A  202303              5          6               6
# 3      000F03E44A  202304              5          6               5
# 4      000F03E44A  202305              5          6               5
# ...           ...     ...            ...        ...             ...
# 86585  FFF0DAC445  202408              3          2               3
# 86586  FFF0DAC445  202409              3          1               3
# 86587  FFF0DAC445  202410              3          2               3
# 86588  FFF0DAC445  202411              3          2               3
# 86589  FFF0DAC445  202412              3          2               3
#
#        RC_M1_UE_CUS_CN  RC_M1_AV_NP_AT  APV_CE_RAT  DLV_SAA_RAT  \
# 0                    5               4         1.0    -999999.9
# ...

# %%
def quaters(x):
    mm = int(str(x['TA_YM'])[-2:])
    return ((mm-1) // 3) + 1

data_prep2['quaters'] = data_prep2.apply(quaters, axis=1)
data_prep2
# Out:
#       ENCODED_MCT   TA_YM  MCT_OPE_MS_CN  RC_M1_SAA  RC_M1_TO_UE_CT  \
# 0      000F03E44A  202301              5          6               5
# 1      000F03E44A  202302              5          6               6
# 2      000F03E44A  202303              5          6               6
# 3      000F03E44A  202304              5          6               5
# 4      000F03E44A  202305              5          6               5
# ...           ...     ...            ...        ...             ...
# 86585  FFF0DAC445  202408              3          2               3
# 86586  FFF0DAC445  202409              3          1               3
# 86587  FFF0DAC445  202410              3          2               3
# 86588  FFF0DAC445  202411              3          2               3
# 86589  FFF0DAC445  202412              3          2               3
#
#        RC_M1_UE_CUS_CN  RC_M1_AV_NP_AT  APV_CE_RAT  DLV_SAA_RAT  \
# 0                    5               4         1.0    -999999.9
# ...

# %%
data_prep2.to_csv('/content/drive/MyDrive/B.S.degree/Capstone2_HelloKitty/dataset/BasicData_Prep4.csv', encoding='cp949')
